# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
cd "C:\Users\aijul\Desktop\dataScience-\Real_Estate_Project\dataset"
# Out:
# C:\Users\aijul\Desktop\dataScience-\Real_Estate_Project\dataset

# %%
df= pd.read_csv('gurgaon_properties_cleaned_v2.csv')

# %%
df.head()
# Out:
#   property_type                 society     sector  price  price_per_sqft  \
# 0          flat  maa bhagwati residency   sector 7   0.45          5000.0
# 1          flat            apna enclave   sector 3   0.50          7692.0
# 2          flat  tulsiani easy in homes  sector 47   0.40          6722.0
# 3          flat     smart world orchard  sector 61   1.47         12250.0
# 4          flat        parkwood westend  sector 92   0.70          5204.0
#
#      area                            areaWithType  bedRoom  bathroom balcony  \
# 0   900.0          Carpet area: 900 (83.61 sq.m.)        2         2       1
# 1   650.0          Carpet area: 650 (60.39 sq.m.)        2         2       1
# 2   595.0          Carpet area: 595 (55.28 sq.m.)        2         2       3
# 3  1200.0        Carpet area: 1200 (111.48 sq.m.)        2         2       2
# 4  1345.0  Super Built up area 1345(124.95 sq.m.)        2         2       3
#
#    floorNum facing       agePossession  super_built_up_area  built_up_area  \
# 0       4.0   West      Relatively New                  NaN            NaN
# 1       1.0   West        Old Property                  NaN            NaN
# 2      12.0    NaN        New Property                  NaN            NaN
# 3       2.0    NaN           Undefined                  NaN            NaN
# 4       5.0    NaN  Under Construction               1345.0            NaN
#
#    carpet_area  study room  servant room  store room  pooja room  others  \
# 0        900.0           0             0           0           0       0
# 1        650.0           0             0           0           0       0
# 2        595.0           0             0           0           0       0
# 3       1200.0           1             0           0           0       0
# 4          NaN           1             0           0           0       0
#
#    furnishing_type  luxury_score
# 0                1            28
# 1                2            37
# 2                1            36
# 3                1            76
# 4                1             0

# %% [markdown]
# ## property_type vs price

# %%
sns.barplot(x=df['property_type'], y=df['price'], estimator=np.median)
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='price'>

# %%
sns.boxplot(x=df['property_type'], y=df['price'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='price'>

# %% [markdown]
# ## property_type vs price_per_sqft

# %%
sns.barplot(x=df['property_type'], y=df['price_per_sqft'], estimator=np.median)
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x=df['property_type'], y=df['price_per_sqft'])
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='price_per_sqft'>

# %%
# check outliers
df[df['price_per_sqft'] > 100000][['property_type','society','sector','price','price_per_sqft','area','areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']]
# Out:
#      property_type                      society     sector  price  \
# 2519          flat           ambience caitriona  sector 24  14.00
# 2626          flat           ambience caitriona  sector 24  14.00
# 3114         house                  independent  sector 38   8.00
# 3151         house         bhim nagar, sector 6   sector 6   0.85
# 3193         house                  independent  sector 12   3.50
# 3200         house                dlf the grove  sector 54   5.70
# 3204         house                    rk excelo  sector 12   0.60
# 3206         house                  independent  sector 28   4.50
# 3211         house                  independent  sector 12   6.00
# 3221         house                  independent   sector 4   0.60
# 3249         house                  independent  sector 24  10.00
# 3256         house                  independent  sector 17   3.50
# 3270         house          huda plot sector 38  sector 38   4.30
# 3276         house                   ardee city  sector 52   5.50
# 3322         house     unitech uniworld resorts  sector 33  10.00
# 3399         house                        ansal  sector 43   1.85
# 3442         house       emaar the palm springs  sector 54  24.00
# 3456         house                  independent  sector 55   1.45
# 3462         house            vatika india next  sector 82   7.00
# 3482         house       dlf city plots phase 2  sector 25  10.00
# 3496         house       dlf city plots phase 2  sector 25  10.50
# 3497         house         eros rosewood villas  sector 49   2.75
# 3543         house       unitech deerwood chase  sector 50   8.45
# 3555         house                  independent  sector 23   2.80
# 3566         house           vipul tatvam villa  sector 48   7.25
# 3677         house  unitech nirvana birch court  sector 50   7.10
# 3689         house     unitech uniworld resorts  sector 33   9.50
# 3713         house                  independent  sector 54   3.75
# 3733         house               uppal southend  sector 49   6.75
# 3751         house                  independent  sector 57   8.00
#
#       price_per_sqft   area  \
# 2519        200000.0  700.0
# 2626        200000.0  700.0
# 3114        230547.0  347.0
# 3151        126865.0   67.0
# 3193        133079.0  263.0
# 3200        211111.0  270.0
# 3204        120000.0   50.0
# 3206        125000.0  360.0
# 3211        315789.0  190.0
# 3221        105263.0   57.0
# 3249        229885.0  435.0
# 3256        218750.0  160.0
# 3270        245398.0  175.0
# 3276        183333.0  300.0
# 3322        181818.0  550.0
# 3399        308333.0   60.0
# 3442        600000.0  400.0
# 3456        241666.0   60.0
# 3462        194444.0  360.0
# 3482        400000.0  250.0
# 3496        261194.0  402.0
# 3497        178571.0  154.0
# 3543        235376.0  359.0
# 3555        161849.0  173.0
# 3566        201388.0  360.0
# 3677        283333.0  251.0
# 3689        173992.0  546.0
# 3713        234375.0  160.0
# 3733        290948.0  232.0
# 3751        266666.0  300.0
#
#                                            areaWithType  super_built_up_area  \
# 2519                   Built Up area: 700 (65.03 sq.m.)                  NaN
# 2626                   Built Up area: 700 (65.03 sq.m.)                  NaN
# 3114  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...                  NaN
# 3151                           Plot area 67(6.22 sq.m.)                  NaN
# 3193  Plot area 263(24.43 sq.m.)Built Up area: 4800 ...                  NaN
# 3200                   Built Up area: 270 (25.08 sq.m.)                  NaN
# 3204  Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...                  NaN
# 3206                   Built Up area: 360 (33.45 sq.m.)                  NaN
# 3211  Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...                  NaN
# 3221                            Plot area 57(5.3 sq.m.)                  NaN
# 3249                     Carpet area: 435 (40.41 sq.m.)                  NaN
# 3256                   Built Up area: 160 (14.86 sq.m.)                  NaN
# 3270  Plot area 163(15.14 sq.m.)Built Up area: 145 s...                  NaN
# 3276                         Plot area 300(27.87 sq.m.)                  NaN
# 3322                          Plot area 550(51.1 sq.m.)                  NaN
# 3399                           Plot area 60(5.57 sq.m.)                  NaN
# 3442                         Plot area 400(37.16 sq.m.)                  NaN
# 3456                           Plot area 60(5.57 sq.m.)                  NaN
# 3462  Plot area 360(33.45 sq.m.)Built Up area: 3900 ...                  NaN
# 3482                         Plot area 250(23.23 sq.m.)                  NaN
# 3496                         Plot area 402(37.35 sq.m.)                  NaN
# 3497  Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...                  NaN
# 3543                         Plot area 359(33.35 sq.m.)                  NaN
# 3555  Plot area 173(16.07 sq.m.)Built Up area: 160 s...                  NaN
# 3566                         Plot area 360(33.45 sq.m.)                  NaN
# 3677                          Plot area 240(22.3 sq.m.)                  NaN
# 3689                         Plot area 546(50.73 sq.m.)                  NaN
# 3713                         Plot area 160(14.86 sq.m.)                  NaN
# 3733                         Plot area 232(21.55 sq.m.)                  NaN
# 3751                         Plot area 300(27.87 sq.m.)                  NaN
#
#       built_up_area  carpet_area
# 2519          700.0          NaN
# 2626          700.0          NaN
# 3114          347.0        215.0
# 3151           67.0          NaN
# 3193         4800.0       4400.0
# 3200          270.0          NaN
# 3204           30.0         15.0
# 3206          360.0          NaN
# 3211            NaN       1600.0
# 3221           57.0          NaN
# 3249            NaN        435.0
# 3256          160.0          NaN
# 3270          145.0          NaN
# 3276          300.0          NaN
# 3322          550.0          NaN
# 3399           60.0          NaN
# 3442          400.0          NaN
# 3456           60.0          NaN
# 3462         3900.0       3743.0
# 3482          250.0          NaN
# 3496          402.0          NaN
# 3497            NaN       1650.0
# 3543          359.0          NaN
# 3555          160.0        150.0
# 3566          360.0          NaN
# 3677          240.0          NaN
# 3689          546.0          NaN
# 3713          160.0          NaN
# 3733          232.0          NaN
# 3751          300.0          NaN

# %%
df.head()
# Out:
#   property_type                 society     sector  price  price_per_sqft  \
# 0          flat  maa bhagwati residency   sector 7   0.45          5000.0
# 1          flat            apna enclave   sector 3   0.50          7692.0
# 2          flat  tulsiani easy in homes  sector 47   0.40          6722.0
# 3          flat     smart world orchard  sector 61   1.47         12250.0
# 4          flat        parkwood westend  sector 92   0.70          5204.0
#
#      area                            areaWithType  bedRoom  bathroom balcony  \
# 0   900.0          Carpet area: 900 (83.61 sq.m.)        2         2       1
# 1   650.0          Carpet area: 650 (60.39 sq.m.)        2         2       1
# 2   595.0          Carpet area: 595 (55.28 sq.m.)        2         2       3
# 3  1200.0        Carpet area: 1200 (111.48 sq.m.)        2         2       2
# 4  1345.0  Super Built up area 1345(124.95 sq.m.)        2         2       3
#
#    floorNum facing       agePossession  super_built_up_area  built_up_area  \
# 0       4.0   West      Relatively New                  NaN            NaN
# 1       1.0   West        Old Property                  NaN            NaN
# 2      12.0    NaN        New Property                  NaN            NaN
# 3       2.0    NaN           Undefined                  NaN            NaN
# 4       5.0    NaN  Under Construction               1345.0            NaN
#
#    carpet_area  study room  servant room  store room  pooja room  others  \
# 0        900.0           0             0           0           0       0
# 1        650.0           0             0           0           0       0
# 2        595.0           0             0           0           0       0
# 3       1200.0           1             0           0           0       0
# 4          NaN           1             0           0           0       0
#
#    furnishing_type  luxury_score
# 0                1            28
# 1                2            37
# 2                1            36
# 3                1            76
# 4                1             0

# %%
sns.heatmap(pd.crosstab(df['property_type'], df['bedRoom']))
# Out:
# <AxesSubplot:xlabel='bedRoom', ylabel='property_type'>
